# %%
import numpy as np

import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20230101", periods=6)
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2023-01-01  0.844894 -1.462960  0.188785 -0.640769
# 2023-01-02 -1.485729 -1.600912  0.792624 -1.337574
# 2023-01-03 -0.843049  0.710067 -0.692971  0.361891
# 2023-01-04 -0.488890 -0.748114  0.381572  1.008773
# 2023-01-05 -0.318554 -1.207396  1.481603 -2.483336
# 2023-01-06 -0.966415  0.334855 -2.210509  0.048772

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.info()

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df.to_numpy()
# Out:
# array([[ 0.84489433, -1.46295963,  0.18878454, -0.64076905],
#        [-1.48572907, -1.60091182,  0.79262392, -1.33757415],
#        [-0.84304938,  0.71006711, -0.69297058,  0.36189112],
#        [-0.48888998, -0.74811449,  0.38157183,  1.00877337],
#        [-0.31855393, -1.20739564,  1.48160282, -2.48333551],
#        [-0.96641493,  0.33485526, -2.21050868,  0.0487722 ]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.542957 -0.662410 -0.009816 -0.507040
# std    0.792162  0.969974  1.293879  1.262939
# min   -1.485729 -1.600912 -2.210509 -2.483336
# 25%   -0.935574 -1.399069 -0.472532 -1.163373
# 50%   -0.665970 -0.977755  0.285178 -0.295998
# 75%   -0.361138  0.064113  0.689861  0.283611
# max    0.844894  0.710067  1.481603  1.008773

# %%
df.T
# Out:
#    2023-01-01  2023-01-02  2023-01-03  2023-01-04  2023-01-05  2023-01-06
# A    0.844894   -1.485729   -0.843049   -0.488890   -0.318554   -0.966415
# B   -1.462960   -1.600912    0.710067   -0.748114   -1.207396    0.334855
# C    0.188785    0.792624   -0.692971    0.381572    1.481603   -2.210509
# D   -0.640769   -1.337574    0.361891    1.008773   -2.483336    0.048772

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2023-01-01 -0.640769  0.188785 -1.462960  0.844894
# 2023-01-02 -1.337574  0.792624 -1.600912 -1.485729
# 2023-01-03  0.361891 -0.692971  0.710067 -0.843049
# 2023-01-04  1.008773  0.381572 -0.748114 -0.488890
# 2023-01-05 -2.483336  1.481603 -1.207396 -0.318554
# 2023-01-06  0.048772 -2.210509  0.334855 -0.966415

# %%
df.sort_values(by=["B"])
# Out:
#                    A         B         C         D
# 2023-01-02 -1.485729 -1.600912  0.792624 -1.337574
# 2023-01-01  0.844894 -1.462960  0.188785 -0.640769
# 2023-01-05 -0.318554 -1.207396  1.481603 -2.483336
# 2023-01-04 -0.488890 -0.748114  0.381572  1.008773
# 2023-01-06 -0.966415  0.334855 -2.210509  0.048772
# 2023-01-03 -0.843049  0.710067 -0.692971  0.361891

# %%
df
# Out:
#                    A         B         C         D
# 2023-01-01  0.844894 -1.462960  0.188785 -0.640769
# 2023-01-02 -1.485729 -1.600912  0.792624 -1.337574
# 2023-01-03 -0.843049  0.710067 -0.692971  0.361891
# 2023-01-04 -0.488890 -0.748114  0.381572  1.008773
# 2023-01-05 -0.318554 -1.207396  1.481603 -2.483336
# 2023-01-06 -0.966415  0.334855 -2.210509  0.048772

# %%
df[["A","B"]]
# Out:
#                    A         B
# 2023-01-01  0.844894 -1.462960
# 2023-01-02 -1.485729 -1.600912
# 2023-01-03 -0.843049  0.710067
# 2023-01-04 -0.488890 -0.748114
# 2023-01-05 -0.318554 -1.207396
# 2023-01-06 -0.966415  0.334855

# %%
df[0:2]
# Out:
#                    A         B         C         D
# 2023-01-01  0.844894 -1.462960  0.188785 -0.640769
# 2023-01-02 -1.485729 -1.600912  0.792624 -1.337574

# %%
df.iloc[0:2,0:3]
# Out:
#                    A         B         C
# 2023-01-01  0.844894 -1.462960  0.188785
# 2023-01-02 -1.485729 -1.600912  0.792624

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2023-01-01  0.844894 -1.462960
# 2023-01-02 -1.485729 -1.600912
# 2023-01-03 -0.843049  0.710067
# 2023-01-04 -0.488890 -0.748114
# 2023-01-05 -0.318554 -1.207396
# 2023-01-06 -0.966415  0.334855

# %%
df.iloc[3]
# Out:
# A   -0.488890
# B   -0.748114
# C    0.381572
# D    1.008773
# Name: 2023-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2023-01-04 -0.488890 -0.748114
# 2023-01-05 -0.318554 -1.207396

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')

# %%
titanic

# %%
titanic.sample(100)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic[titanic["age"] <1]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 831         1       2    male  0.83      1      1   18.7500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 78   child       False  NaN  Southampton   yes  False
# 305  child       False    C  Southampton   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 803  child       False  NaN    Cherbourg   yes  False
# 831  child       False  NaN  Southampton   yes  False

# %%
titanic[titanic["fare"] <3]
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 179         0       3  male  36.0      0      0   0.0        S   Third  man
# 263         0       1  male  40.0      0      0   0.0        S   First  man
# 271         1       3  male  25.0      0      0   0.0        S   Third  man
# 277         0       2  male   NaN      0      0   0.0        S  Second  man
# 302         0       3  male  19.0      0      0   0.0        S   Third  man
# 413         0       2  male   NaN      0      0   0.0        S  Second  man
# 466         0       2  male   NaN      0      0   0.0        S  Second  man
# 481         0       2  male   NaN      0      0   0.0        S  Second  man
# 597         0       3  male  49.0      0      0   0.0        S   Third  man
# 633         0       1  male   NaN      0      0   0.0        S   First  man
# 674         0       2  male   NaN      0      0   0.0        S  Second  man
# 732         0       2  male   NaN      0      0   0.0        S  Second  man
# 806         0       1  male  39.0      0      0   0.0        S   First  man
# 815         0       1  male   NaN      0      0   0.0        S   First  man
# 822         0       1  male  38.0      0      0   0.0        S   First  man
#
#      adult_male deck  embark_town alive  alone
# 179        True  NaN  Southampton    no   True
# 263        True    B  Southampton    no   True
# 271        True  NaN  Southampton   yes   True
# 277        True  NaN  Southampton    no   True
# 302        True  NaN  Southampton    no   True
# 413        True  NaN  Southampton    no   True
# 466        True  NaN  Southampton    no   True
# 481        True  NaN  Southampton    no   True
# 597        True  NaN  Southampton    no   True
# 633        True  NaN  Southampton    no   True
# 674        True  NaN  Southampton    no   True
# 732        True  NaN  Southampton    no   True
# 806        True    A  Southampton    no   True
# 815        True    B  Southampton    no   True
# 822        True  NaN  Southampton    no   True
